# %% [markdown]
# <a href="https://colab.research.google.com/github/liebe1127/ai-programming-2026/blob/main/week01/week01_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TODO: ___ 를 본인 이름과 학과로 바꾸세요.
print('이름:', '배준호')
print('학과:', '정보컴퓨터공학부')

print("기대: 위 두 줄의 밑줄 자리가 본인 이름과 학과로 바뀌어 출력됩니다")
# Out:
# 이름: 배준호
# 학과: 정보컴퓨터공학부
# 기대: 위 두 줄의 밑줄 자리가 본인 이름과 학과로 바뀌어 출력됩니다

# %%
# !git clone https://github.com/octocat/Hello-World.git
# Out:
# fatal: destination path 'Hello-World' already exists and is not an empty directory.

# %%
# %cd Hello-World
# !ls
# Out:
# /content/Hello-World
# ai-programming-2026  README

# %%
# %cd /content
# !git clone https://github.com/liebe1127/ai-programming-2026.git
# %cd ai-programming-2026
# !ls week01
# Out:
# /content
# Cloning into 'ai-programming-2026'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.
# /content/ai-programming-2026
# hello.txt
